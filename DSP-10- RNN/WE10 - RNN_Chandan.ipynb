# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU, Conv1D, Flatten
from tensorflow.keras.optimizers import Adam

# %%
# Reading Amgen Stock data

df_amgen = pd.read_csv('AMGN.csv')

# %%
df_amgen.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  02-08-2022  246.690002  247.850006  243.779999  243.910004  238.283737
# 1  03-08-2022  245.940002  249.330002  245.179993  247.139999  241.439224
# 2  04-08-2022  247.000000  249.000000  246.199997  246.979996  241.282913
# 3  05-08-2022  246.460007  247.080002  241.789993  246.250000  240.569763
# 4  08-08-2022  245.000000  247.740005  244.309998  247.289993  241.585754
#
#     Volume
# 0  2295100
# 1  2061400
# 2  2650600
# 3  2723900
# 4  2784400

# %%
# data info

df_amgen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       180 non-null    object
#  1   Open       180 non-null    float64
#  2   High       180 non-null    float64
#  3   Low        180 non-null    float64
#  4   Close      180 non-null    float64
#  5   Adj Close  180 non-null    float64
#  6   Volume     180 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 10.0+ KB

# %%
# We are going to predict Closing price, so dropping rest features

df_amgen = df_amgen[['Date', 'Close']]

# %%
df_amgen.head()
# Out:
#          Date       Close
# 0  02-08-2022  243.910004
# 1  03-08-2022  247.139999
# 2  04-08-2022  246.979996
# 3  05-08-2022  246.250000
# 4  08-08-2022  247.289993

# %%
# zero NA's and missing values and outliers

plt.plot(df_amgen['Close'])

# %% [markdown]
# ## Reshape for Standardizing data

# %%
# Let's create a single sequence (i.e., feature) for standardization
price_close = np.array(df_amgen['Close']).reshape(-1, 1)

price_close.shape
# Out:
# (180, 1)

# %% [markdown]
# ## Standardize the feature

# %%
scaler = StandardScaler()
price_close_scaled = scaler.fit_transform(price_close)

# %% [markdown]
# ### Predicting a time series object which needs to be in chronological order

# %%
# Splitting based on order

split_point = int(len(price_close_scaled) * 0.7)
train, test = price_close_scaled[:split_point], price_close_scaled[split_point:]

# %% [markdown]
# ## Let's keep it simple and create X_train, X_test, y_train, y_test using a 9:1 ratio as we are predicting 10th day price based on last 9 days

# %%
# 9 days split
num_cols = 9


X_train = []
y_train = []
for i in range(len(train) - num_cols):
    X_train.append(train[i:i+num_cols])
    y_train.append(train[i+num_cols])

X_train, y_train = np.array(X_train), np.array(y_train)

X_test = []
y_test = []
for i in range(len(test) - num_cols):
    X_test.append(test[i:i+num_cols])
    y_test.append(test[i+num_cols])

X_test, y_test = np.array(X_test), np.array(y_test)

# %%
X_train[1]
# Out:
# array([[-0.28447413],
#        [-0.2932459 ],
#        [-0.33326611],
#        [-0.27625108],
#        [-0.21759055],
#        [-0.01310285],
#        [-0.2181385 ],
#        [-0.21594599],
#        [-0.06847326]])

# %%
X_test[1]
# Out:
# array([[-0.32449429],
#        [-0.31791586],
#        [-0.39247454],
#        [-0.46483982],
#        [-0.45661677],
#        [-0.66494249],
#        [-0.67590683],
#        [-0.53885054],
#        [-0.47525621]])

# %%
y_train[1]
# Out:
# array([0.04500891])

# %%
y_test[1]
# Out:
# array([-0.61943969])

# %% [markdown]
# ## Simple RNN

# %%
rnn_model = keras.models.Sequential([
    keras.layers.SimpleRNN(32, activation='relu', input_shape=[9, 1]),
    keras.layers.Dense(1, activation=None)
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

rnn_model.compile(loss="mse", optimizer='Adam')

# %%
# Train the model
history = rnn_model.fit(X_train, y_train, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 10ms/step - loss: 1.3088
# Epoch 2/50
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1393
# Epoch 3/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9835
# Epoch 4/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8406
# Epoch 5/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7160
# Epoch 6/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6104
# Epoch 7/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5257
# Epoch 8/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4384
# Epoch 9/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3591
# Epoch 10/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2875
# Epoch 11/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2326
# Epoch 12/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1874
# Epoch 13/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1580
# Epoch 14/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1391
# Epoch 15/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1330
# Epoch 16/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1322
# Epoch 17/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1308
# Epoch 18/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1245
# Epoch 19/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1129
# Epoch 20/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0991
# Epoch 21/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0884
# Epoch 22/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0797
# Epoch 23/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0761
# Epoch 24/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0759
# Epoch 25/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0758
# Epoch 26/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0744
# Epoch 27/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0727
# Epoch 28/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0705
# Epoch 29/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0695
# Epoch 30/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0685
# Epoch 31/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0687
# Epoch 32/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0685
# Epoch 33/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0681
# Epoch 34/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0674
# Epoch 35/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0667
# Epoch 36/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0658
# Epoch 37/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0652
# Epoch 38/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0647
# Epoch 39/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0644
# Epoch 40/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0640
# Epoch 41/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0638
# Epoch 42/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0634
# Epoch 43/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0630
# Epoch 44/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0626
# Epoch 45/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0623
# Epoch 46/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0619
# Epoch 47/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0614
# Epoch 48/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0610
# Epoch 49/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0607
# Epoch 50/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0602

# %% [markdown]
# ## Predictions

# %%
#Predict:
y_pred = rnn_model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
#Remember, these are standardized values. 

comparison = pd.DataFrame()

comparison['actual'] = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
comparison['predicted'] = scaler.inverse_transform(y_pred).flatten()

# %%
comparison
# Out:
#         actual   predicted
# 0   243.660004  241.105331
# 1   241.029999  242.554565
# 2   240.070007  240.976349
# 3   234.220001  239.951141
# 4   240.529999  236.190674
# 5   238.240005  238.485458
# 6   236.160004  237.902878
# 7   237.619995  237.036484
# 8   233.660004  236.929855
# 9   234.449997  234.944977
# 10  231.660004  234.598709
# 11  236.190002  232.885803
# 12  234.740005  234.967468
# 13  234.809998  234.820190
# 14  235.110001  234.927979
# 15  228.720001  234.793884
# 16  228.429993  231.416992
# 17  225.789993  229.768768
# 18  227.869995  227.794098
# 19  233.179993  228.292175
# 20  230.580002  231.919037
# 21  234.899994  231.431488
# 22  234.570007  234.128006
# 23  229.789993  234.069092
# 24  234.720001  231.745621
# 25  232.949997  233.348022
# 26  229.830002  232.968292
# 27  233.100006  231.540344
# 28  238.029999  232.429779
# 29  236.759995  236.287277
# 30  238.479996  236.634186
# 31  241.029999  237.860260
# 32  241.500000  239.739258
# 33  241.750000  240.666992
# 34  244.440002  241.010574
# 35  247.529999  243.051819
# 36  253.369995  246.260544
# 37  253.320007  252.061768
# 38  250.899994  254.027390
# 39  251.429993  252.489990
# 40  249.500000  252.159286
# 41  251.440002  250.377426
# 42  250.000000  251.120056
# 43  248.070007  250.602646
# 44  246.089996  248.372833
# 45  246.210007  246.016068

# %%
rnn_model_mse = mean_squared_error(comparison['actual'], comparison['predicted'])

# %%
plt.plot(comparison['actual'], label = 'actual')
plt.plot(comparison['predicted'], label = 'predicted')

plt.legend()

plt.show()

# %% [markdown]
# ## LSTM with 2 Layers

# %%
lstm_model = keras.models.Sequential([
    keras.layers.LSTM(32, activation='tanh', return_sequences=True, input_shape=[9, 1]),
    keras.layers.LSTM(32, activation='tanh', return_sequences=False),
    keras.layers.Dense(1, activation=None)
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

lstm_model.compile(loss="mse", optimizer='Adam')

# %%
# Train the model
history = lstm_model.fit(X_train, y_train, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 4s 12ms/step - loss: 1.0718
# Epoch 2/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9419
# Epoch 3/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8183
# Epoch 4/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6978
# Epoch 5/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5837
# Epoch 6/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4800
# Epoch 7/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3956
# Epoch 8/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3320
# Epoch 9/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2973
# Epoch 10/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2915
# Epoch 11/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2892
# Epoch 12/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2805
# Epoch 13/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2637
# Epoch 14/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2438
# Epoch 15/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2267
# Epoch 16/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2184
# Epoch 17/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2134
# Epoch 18/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2149
# Epoch 19/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2166
# Epoch 20/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2175
# Epoch 21/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2179
# Epoch 22/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2160
# Epoch 23/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2131
# Epoch 24/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2100
# Epoch 25/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2070
# Epoch 26/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2041
# Epoch 27/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2031
# Epoch 28/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2019
# Epoch 29/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2014
# Epoch 30/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2003
# Epoch 31/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1989
# Epoch 32/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1979
# Epoch 33/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1966
# Epoch 34/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1953
# Epoch 35/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1940
# Epoch 36/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1928
# Epoch 37/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1916
# Epoch 38/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1904
# Epoch 39/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1891
# Epoch 40/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1881
# Epoch 41/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1867
# Epoch 42/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1853
# Epoch 43/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1840
# Epoch 44/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1827
# Epoch 45/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1814
# Epoch 46/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1800
# Epoch 47/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1788
# Epoch 48/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1773
# Epoch 49/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1764
# Epoch 50/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1747

# %%
#Predict:
y_pred = lstm_model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 4ms/step

# %%
#Remember, these are standardized values. 

comparison = pd.DataFrame()

comparison['actual'] = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
comparison['predicted'] = scaler.inverse_transform(y_pred).flatten()

# %%
comparison
# Out:
#         actual   predicted
# 0   243.660004  244.809799
# 1   241.029999  243.924103
# 2   240.070007  243.450867
# 3   234.220001  242.932465
# 4   240.529999  242.143982
# 5   238.240005  241.595016
# 6   236.160004  241.049591
# 7   237.619995  240.615463
# 8   233.660004  240.202881
# 9   234.449997  239.483902
# 10  231.660004  238.694855
# 11  236.190002  237.946732
# 12  234.740005  237.433136
# 13  234.809998  237.275085
# 14  235.110001  236.835205
# 15  228.720001  236.616562
# 16  228.429993  236.246048
# 17  225.789993  235.619812
# 18  227.869995  234.979782
# 19  233.179993  234.263992
# 20  230.580002  233.930283
# 21  234.899994  233.478577
# 22  234.570007  233.399475
# 23  229.789993  233.527542
# 24  234.720001  233.561310
# 25  232.949997  234.026474
# 26  229.830002  234.466110
# 27  233.100006  234.801514
# 28  238.029999  234.999847
# 29  236.759995  235.195938
# 30  238.479996  235.649994
# 31  241.029999  236.051773
# 32  241.500000  236.727325
# 33  241.750000  237.793060
# 34  244.440002  238.668137
# 35  247.529999  239.804565
# 36  253.369995  241.329468
# 37  253.320007  243.151230
# 38  250.899994  244.981293
# 39  251.429993  246.809952
# 40  249.500000  248.400772
# 41  251.440002  249.520584
# 42  250.000000  250.480850
# 43  248.070007  251.169342
# 44  246.089996  251.356247
# 45  246.210007  251.013199

# %%
lstm_mse = mean_squared_error(comparison['actual'], comparison['predicted'])

# %%
plt.plot(comparison['actual'], label = 'actual')
plt.plot(comparison['predicted'], label = 'predicted')

plt.legend()

plt.show()

# %% [markdown]
# ## GRU (With more layers)

# %%
gru_model = keras.models.Sequential([
    keras.layers.GRU(32, activation='relu', return_sequences=True, input_shape=[9, 1]),
    keras.layers.GRU(32, activation='relu', return_sequences=False),
    keras.layers.Dense(1, activation=None)
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

gru_model.compile(loss="mse", optimizer='Adam')

# %%
# Train the model
history = gru_model.fit(X_train, y_train, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 10ms/step - loss: 1.0309
# Epoch 2/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9386
# Epoch 3/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8558
# Epoch 4/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7764
# Epoch 5/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7019
# Epoch 6/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6296
# Epoch 7/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5619
# Epoch 8/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4946
# Epoch 9/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4322
# Epoch 10/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3755
# Epoch 11/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3278
# Epoch 12/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2846
# Epoch 13/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2511
# Epoch 14/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2238
# Epoch 15/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2062
# Epoch 16/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1932
# Epoch 17/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1813
# Epoch 18/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1678
# Epoch 19/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1512
# Epoch 20/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1343
# Epoch 21/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1246
# Epoch 22/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1150
# Epoch 23/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1100
# Epoch 24/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1081
# Epoch 25/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1056
# Epoch 26/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1023
# Epoch 27/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0988
# Epoch 28/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0946
# Epoch 29/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0917
# Epoch 30/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0891
# Epoch 31/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0868
# Epoch 32/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0851
# Epoch 33/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0830
# Epoch 34/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0811
# Epoch 35/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0787
# Epoch 36/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0769
# Epoch 37/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0751
# Epoch 38/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0733
# Epoch 39/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0706
# Epoch 40/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0686
# Epoch 41/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0663
# Epoch 42/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0641
# Epoch 43/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0613
# Epoch 44/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0591
# Epoch 45/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0575
# Epoch 46/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0561
# Epoch 47/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0539
# Epoch 48/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0529
# Epoch 49/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0511
# Epoch 50/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0497

# %%
#Predict:
y_pred = gru_model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 4ms/step

# %%
#Remember, these are standardized values. 

comparison = pd.DataFrame()

comparison['actual'] = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
comparison['predicted'] = scaler.inverse_transform(y_pred).flatten()

# %%
comparison
# Out:
#         actual   predicted
# 0   243.660004  240.926071
# 1   241.029999  242.420868
# 2   240.070007  241.012695
# 3   234.220001  239.722198
# 4   240.529999  235.101288
# 5   238.240005  238.355728
# 6   236.160004  237.930099
# 7   237.619995  236.110352
# 8   233.660004  236.707062
# 9   234.449997  233.960480
# 10  231.660004  233.769073
# 11  236.190002  231.653946
# 12  234.740005  234.878479
# 13  234.809998  234.558258
# 14  235.110001  234.415176
# 15  228.720001  234.622070
# 16  228.429993  229.334320
# 17  225.789993  227.978516
# 18  227.869995  225.738235
# 19  233.179993  227.323120
# 20  230.580002  232.388290
# 21  234.899994  230.864166
# 22  234.570007  234.296005
# 23  229.789993  234.431717
# 24  234.720001  229.783707
# 25  232.949997  233.709839
# 26  229.830002  232.793045
# 27  233.100006  229.825974
# 28  238.029999  232.248825
# 29  236.759995  237.089828
# 30  238.479996  236.711258
# 31  241.029999  237.865784
# 32  241.500000  240.177200
# 33  241.750000  240.890625
# 34  244.440002  241.084732
# 35  247.529999  243.227402
# 36  253.369995  246.237015
# 37  253.320007  251.695084
# 38  250.899994  253.079422
# 39  251.429993  251.319550
# 40  249.500000  250.893234
# 41  251.440002  249.344635
# 42  250.000000  250.167313
# 43  248.070007  249.590378
# 44  246.089996  247.981796
# 45  246.210007  245.960938

# %%
gru_mse = mean_squared_error(comparison['actual'], comparison['predicted'])

# %%
plt.plot(comparison['actual'], label = 'actual')
plt.plot(comparison['predicted'], label = 'predicted')

plt.legend()

plt.show()

# %% [markdown]
# ## Conv1D

# %%
conv1d_model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=3, strides=1, padding="valid", input_shape=[9, 1]),
    keras.layers.GRU(32, activation='relu', return_sequences=True),
    keras.layers.GRU(32, activation='relu', return_sequences=False),
    keras.layers.Dense(1, activation=None)
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

conv1d_model.compile(loss="mse", optimizer='Adam')

history = conv1d_model.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 4/4 [==============================] - 3s 7ms/step - loss: 1.1192
# Epoch 2/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9252
# Epoch 3/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7409
# Epoch 4/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5695
# Epoch 5/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4056
# Epoch 6/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2956
# Epoch 7/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2519
# Epoch 8/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2135
# Epoch 9/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1616
# Epoch 10/30
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1428
# Epoch 11/30
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1560
# Epoch 12/30
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1542
# Epoch 13/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1390
# Epoch 14/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1309
# Epoch 15/30
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1298
# Epoch 16/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1266
# Epoch 17/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1218
# Epoch 18/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1176
# Epoch 19/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1138
# Epoch 20/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1097
# Epoch 21/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1057
# Epoch 22/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1014
# Epoch 23/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0974
# Epoch 24/30
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0931
# Epoch 25/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0892
# Epoch 26/30
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0853
# Epoch 27/30
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0821
# Epoch 28/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0790
# Epoch 29/30
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0754
# Epoch 30/30
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0729

# %%
#Predict:
y_pred = conv1d_model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 4ms/step

# %%
#Remember, these are standardized values. 

comparison = pd.DataFrame()

comparison['actual'] = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
comparison['predicted'] = scaler.inverse_transform(y_pred).flatten()

# %%
comparison
# Out:
#         actual   predicted
# 0   243.660004  240.248795
# 1   241.029999  241.666733
# 2   240.070007  241.521683
# 3   234.220001  240.245026
# 4   240.529999  237.696182
# 5   238.240005  237.160187
# 6   236.160004  238.768280
# 7   237.619995  237.363739
# 8   233.660004  236.888855
# 9   234.449997  235.893005
# 10  231.660004  234.527542
# 11  236.190002  233.665482
# 12  234.740005  234.286392
# 13  234.809998  235.766968
# 14  235.110001  235.323730
# 15  228.720001  235.458084
# 16  228.429993  233.025757
# 17  225.789993  230.071152
# 18  227.869995  228.773758
# 19  233.179993  228.561584
# 20  230.580002  232.256531
# 21  234.899994  233.601746
# 22  234.570007  234.206390
# 23  229.789993  235.984299
# 24  234.720001  233.535461
# 25  232.949997  233.346207
# 26  229.830002  234.712082
# 27  233.100006  232.605011
# 28  238.029999  232.537781
# 29  236.759995  236.164459
# 30  238.479996  237.866257
# 31  241.029999  237.925934
# 32  241.500000  239.571655
# 33  241.750000  240.807343
# 34  244.440002  241.112000
# 35  247.529999  242.138428
# 36  253.369995  244.747604
# 37  253.320007  249.342468
# 38  250.899994  253.302322
# 39  251.429993  253.508987
# 40  249.500000  252.665894
# 41  251.440002  251.636093
# 42  250.000000  251.056213
# 43  248.070007  250.971008
# 44  246.089996  249.758377
# 45  246.210007  247.759674

# %%
conv1d_mse = mean_squared_error(comparison['actual'], comparison['predicted'])

# %%
plt.plot(comparison['actual'], label = 'actual')
plt.plot(comparison['predicted'], label = 'predicted')

plt.legend()

plt.show()

# %%
print('Root Mean Squared Error for SimpleRNN Model is:' + str(rnn_model_mse))
print('Root Mean Squared Error for LSTM Model is:' + str(lstm_mse))
print('Root Mean Squared Error for GRU Model is:' + str(gru_mse))
print('Root Mean Squared Error for Conv1D Model is:' + str(conv1d_mse))
# Out:
# Root Mean Squared Error for SimpleRNN Model is:8.691265485435457
# Root Mean Squared Error for LSTM Model is:25.091690079898548
# Root Mean Squared Error for GRU Model is:9.239494726390626
# Root Mean Squared Error for Conv1D Model is:10.682944505289637

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## The Root Mean Squared Error (RMSE) values have been calculated for various models and are as follows:
#
# ## SimpleRNN: 8.6912
# ## LSTM: 25.0916
# ## GRU: 9.2394
# ## Conv1D: 10.6829
# ## Based on the RMSE values, it can be observed that the SimpleRNN model outperforms the other models, with GRU coming in second place, followed by the Conv1D model, and finally the LSTM model. While the RMSE values provide a useful metric for evaluating the performance of different models, it's important to keep in mind that they are not the only factor to consider. Other factors such as training time, complexity, and interpretability may also play a role in determining the best model for a given task. Therefore, it's important to carefully consider all of these factors when selecting a model for your specific application. Additionally, it's always a good idea to experiment with different models and hyperparameters to find the best possible solution for your particular problem.
